# %%
from sqlalchemy import create_engine, inspect
import pandas as pd

# %%
pgeng = create_engine("postgresql://postgres:postgres@localhost:5432/verndardb", echo=True)

# %%
i = inspect(pgeng)
# Out:
# 2025-11-28 15:15:09,044 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-11-28 15:15:09,046 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-28 15:15:09,049 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-11-28 15:15:09,051 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-11-28 15:15:09,053 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-11-28 15:15:09,054 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
i.get_table_names()
# Out:
# 2025-11-28 15:15:28,106 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-11-28 15:15:28,108 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s]) AND pg_catalog.pg_class.relpersistence != %(relpersistence_1)s AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2025-11-28 15:15:28,109 INFO sqlalchemy.engine.Engine [generated in 0.00305s] {'param_1': 'r', 'param_2': 'p', 'relpersistence_1': 't', 'nspname_1': 'pg_catalog'}
# 2025-11-28 15:15:28,116 INFO sqlalchemy.engine.Engine ROLLBACK
# []
